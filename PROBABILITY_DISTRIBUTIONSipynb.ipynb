# %%
import numpy as np

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from numpy import random
import seaborn as sns

x = random.eimport matplotlib.pyplot as plt
xponential(scale=1, size=100)
sns.distplot(x,color='black')
plt.show()
# Out:
#   File "<ipython-input-30-d591e6e40e21>", line 4
#     x = random.eimport matplotlib.pyplot as plt
#                                 ^
# SyntaxError: invalid syntax

# %%
x=random.normal(loc=0,scale=2,size=100)
sns.distplot(x,color='black',hist=False)

y=random.normal(loc=0,scale=5,size=100)
sns.distplot(y,color='green',hist=False)

z=random.normal(loc=-3,scale=2,size=100)
sns.distplot(z,color='red',hist=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
x=np.random.normal(0,2,100)
y=np.random.normal(0,5,100)
z=np.random.normal(-2,5,100)
sns.distplot(x,color='black',hist=False)
sns.distplot(y,color='red',hist=False)
sns.distplot(z,color='green',hist=False)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
import random
print(random.random())
# Out:
# 0.5009117276466015

# %%
import numpy as np
np.random.uniform(low=1,high=3,size=50)
# Out:
# array([2.00678318, 2.69397511, 1.80350396, 2.50109759, 1.35746881,
#        1.36617469, 1.82450094, 2.14208743, 2.45634512, 2.85764723,
#        1.58974111, 2.85241283, 2.84855699, 1.22618155, 1.59107874,
#        2.76414932, 1.24727819, 1.42805582, 2.61680772, 2.54178125,
#        2.4976002 , 1.77610196, 2.542553  , 1.05697504, 2.81227777,
#        2.61859397, 1.009692  , 1.69111315, 2.56295742, 2.70498398,
#        2.17421848, 2.40574055, 2.03051382, 1.6261162 , 2.76049143,
#        2.54852907, 2.56386746, 2.94392424, 2.48412167, 2.30646661,
#        2.26486059, 1.58407547, 1.5348211 , 2.66711084, 2.70156981,
#        1.59233318, 2.26086621, 2.67012428, 1.4722525 , 1.32424147])

# %%
l=[]
for i in range(0,10):
    l.append(random.random())

# %%
l
# Out:
# [0.09071301334386506,
#  0.42451918914251396,
#  0.8268521246720381,
#  0.12380196114964559,
#  0.22323896460701453,
#  0.6274332224055893,
#  0.9477089424570057,
#  0.5771029486174987,
#  0.39668047465078016,
#  0.9762551055929201]

# %%
## QQ PLOT 

import pylab
import scipy.stats as stats

#x=np.random.uniform(low=0,high=10,size=10000)

#x= np.random.normal(loc=0,scale=10,size=10000)

#x=np.random.uniform(low=1,high=3,size=1000)
x = np.random.exponential(scale=2, size=10000)
stats.probplot(x,dist='norm',plot=pylab)  #norm---normal(0,1)

pylab.show()

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=np.random.lognormal(mean=0,sigma=1,size=10000)
sns.distplot(x,color='black')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
x=np.random.lognormal(mean=0,sigma=1,size=1000)
y=np.random.lognormal(mean=0,sigma=0.5,size=1000)
sns.distplot(x,color='black',hist=False)
sns.distplot(y,color='red',hist=False)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
x=np.random.pareto(a=10,size=1000)
sns.distplot(x,color='black',hist=False)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# import numpy
import numpy as np
import matplotlib.pyplot as plt
  
# Using numpy.random.pareto() method
gfg = np.random.pareto(2.45, 1000)
sns.distplot(gfg,color='black',hist=False)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
import scipy.stats as stats
x=stats.boxcox(gfg,2)

# %%
stats.probplot(x,dist='norm',plot=pylab)  #norm---normal(0,1)

pylab.show()

# %%
from re import X
import numpy as np

x = np.array([[3,1,4],[5,1,3]])



covariance = np.cov(x)

print(covariance)

print(covariance[0][0])
# Out:
# [[2.33333333 2.        ]
#  [2.         4.        ]]
# 2.3333333333333335

# %%
array1 = np.array([[3,1,4],[5,1,3]])
print("Covarinace matrix of x:\n", np.cov(array1))
# Out:
# Covarinace matrix of x:
#  [[2.33333333 2.        ]
#  [2.         4.        ]]

# %%
x = np.array([2,4,1,6,2,1,7,5,8])

#print(x)

y = np.array([7,2,3,1,8,6,2,3,4])

#print(y)

Sigma = np.cov(x,y)

print(Sigma)
# Out:
# [[ 7.   -3.75]
#  [-3.75  6.  ]]

# %%
import pandas as pd
from scipy.stats import pearsonr
 

x = np.array([2,4,1,6,2,1,7,5,8])
y = np.array([7,2,3,1,8,6,2,3,4])
 
# Apply the pearsonr()
corrr, pvalue = pearsonr(x, y)
print('Pearsons correlation: %.3f' % corrr)
# Out:
# Pearsons correlation: -0.579

# %%
from scipy import stats
stats.spearmanr(x,y)
# Out:
# SpearmanrResult(correlation=-0.4703389830508475, pvalue=0.20136002159300917)

# %%
# Out:
# (10000,)

# %%
#CLT

population=np.random.exponential(scale=10,size=10000)
print(population.shape)
pop_mean=np.round(np.mean(population),2)
print(pop_mean)
# Out:
# (10000,)
# 10.06

# %%
samples_mean=[]
for i in range(0,1000):
  sample=np.random.choice(population, size=1000)
 
  
  samples_mean.append(np.round(np.mean(sample),2))

# %%
print(len(samples_mean))
# Out:
# 1000

# %%
np.mean(samples_mean)
# Out:
# 10.05124

# %%
print(np.round(np.std(population),2))
print(np.round(np.std(samples_mean/1000**0.5),2))
# Out:
# 10.14
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-563890544281> in <module>
#       1 print(np.round(np.std(population),2))
# ----> 2 print(np.round(np.std(samples_mean/1000**0.5),2))
#
# TypeError: unsupported operand type(s) for /: 'list' and 'float'

# %%
pop_mean=np.round(np.mean(population),2)

samples_mean=[]
for i in range(0,100):
  sample=np.random.choice(population, size=1000)
 
  
  samples_mean.append(np.round(np.mean(sample),2)) 

print(len(samples_mean))
print(samples_mean)

print(pop_mean)
print(np.mean(samples_mean))
# Out:
# 100
# [10.22, 9.89, 9.61, 9.58, 9.8, 9.7, 10.29, 10.63, 10.09, 10.42, 9.96, 10.13, 9.59, 10.53, 10.0, 10.05, 10.49, 9.79, 10.3, 10.0, 9.78, 9.69, 9.72, 9.75, 10.18, 10.03, 10.32, 9.9, 10.02, 10.06, 9.81, 10.4, 9.62, 9.99, 9.88, 10.23, 10.68, 10.14, 10.19, 9.78, 10.33, 9.93, 9.94, 9.55, 9.64, 10.11, 9.88, 9.57, 10.24, 10.15, 10.44, 10.48, 10.34, 11.09, 10.42, 10.17, 9.99, 10.71, 9.92, 10.05, 10.3, 10.07, 9.57, 9.86, 9.38, 9.67, 9.82, 9.95, 10.48, 9.84, 10.14, 9.71, 10.21, 10.1, 10.45, 10.13, 9.78, 10.31, 9.68, 10.2, 9.69, 9.61, 9.87, 9.89, 10.65, 10.06, 9.84, 10.13, 10.56, 10.3, 9.31, 9.77, 10.22, 10.09, 10.44, 9.75, 9.91, 10.45, 10.45, 9.93]
# 10.06
# 10.0476
